# %%
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt
#import seaborn as sns

# %matplotlib inline

plt.rcParams["figure.figsize"] = (12, 6)

# %%
with open("heat_map_example.pkl","rb") as f:
    heat_map = pkl.load(f)

# %%
plt.matshow(heat_map)
